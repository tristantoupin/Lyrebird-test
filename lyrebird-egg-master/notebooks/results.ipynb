# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# X_train size: (100, 50, 3)
# y_train size: (100, 3)
# X_test size: (100, 50, 3)
# y_test size: (100, 3)
# HBox(children=(IntProgress(value=0), HTML(value=u'')))
# ('Epoch 0/100', ' Current loss: 9.64975643158')
# ('Epoch 10/100', ' Current loss: 7.43272781372')
# ('Epoch 20/100', ' Current loss: 5.60669183731')
# ('Epoch 30/100', ' Current loss: 5.17753362656')
# ('Epoch 40/100', ' Current loss: 4.96027469635')

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke[:200])

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print text
